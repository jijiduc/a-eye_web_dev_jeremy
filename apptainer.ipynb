# %% [markdown]
# migration from dockerhub
#
# https://wiki.isc-vs.ch/doku.php?id=infra:howto:apptainer_sample#from_dockerhub

# %%
# in chacha/disco
apptainer build ./datasets/nnunetv2.sif docker://jaimebarran/nnunet:0.1.0

# %% [markdown]
# copy nnUNet main folder to 'dance'

# %%
scp -r /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/35subs jaime.barrancohernandez@chacha:/home/jaime.barrancohernandez/datasets/

# %% [markdown]
# slurm jobfile using GPU
#
# https://wiki.isc-vs.ch/doku.php?id=infra:howto:slurm_sample#example_using_gpus

# %%
#!/bin/bash
#SBATCH --job-name=nnv2_inf    # job name
#SBATCH --nodes=1              # number of nodes to use
#SBATCH --ntasks=1             # total number of tasks across all nodes
#SBATCH --cpus-per-task=10     # cpu-cores per task (>1 if multi-threaded tasks)
#SBATCH --mem=64gb             # total memory (--mem-per-cpu per cpu-core 4G is default)
#SBATCH --time=1-23:59:00      # total run time limit (HH:MM:SS)
#SBATCH --gres=gpu:1           # number of gpus per node
#SBATCH --output=%N.%j.%a.out  # output log
#SBATCH --error=%N.%j.%a.err   # error log
#SBATCH --mail-type=BEGIN,END  # send email when job begins and ends
#SBATCH --mail-user=jaime.barrancohernandez@hevs.ch

apptainer exec \
    --nv \
    --bind /home/jaime.barrancohernandez/datasets/nnunetv2/35subs:/opt/nnunet_resources \
    --bind /home/jaime.barrancohernandez/datasets/nnunetv2/35subs/nnUNet_inference/input:/input \
    --bind /home/jaime.barrancohernandez/results:/output \
    /home/jaime.barrancohernandez/datasets/nnunetv2/nnunetv2.sif \
    nnUNetv2_predict \
    -d Dataset313_Eye \
    -i /input \
    -o /output \
    -f 0 1 2 3 4 \
    -tr nnUNetTrainer \
    -c 3d_fullres \
    -p nnUNetPlans

# %% [markdown]
# slurm jobfile using an interactive shell
#
# https://wiki.isc-vs.ch/doku.php?id=infra:howto:slurm_sample#example_using_an_interactive_shell

# %%
# without GPU
srun --cpus-per-task=12 --time=3:00:00 --mem=24G --pty apptainer shell /home/jaime.barrancohernandez/datasets/nnunetv2/nnunetv2.sif

# with GPU
srun -G 1 --cpus-per-task=10 --time=3:00:00 --mem=24G --pty apptainer shell --nv /home/jaime.barrancohernandez/datasets/nnunetv2/nunetv2.sif
