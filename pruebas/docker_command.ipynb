# %%
# nnUNet v1 - Pedro
sudo docker run --rm --gpus all --shm-size=10gb -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNet:/opt/nnunet_resources petermcgor/nnunet:0.0.1 nnUNet_predict -i /opt/nnunet_resources/nnUNet_inference/input -o /opt/nnunet_resources/nnUNet_inference/output -tr nnUNetTrainerV2 -ctr nnUNetTrainerV2CascadeFullRes -m 3d_fullres -p nnUNetPlansv2.1 -t Task313_Eye
# nnUNet v1 with trained model - Jaime
sudo docker run --rm --gpus all --shm-size=10gb --entrypoint=/bin/bash -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNet/nnUNet_inference:/tmp jaimebarran/fw_gear_aeye:0.0.1 -c "nnUNet_predict -i /tmp/input -o /tmp/output -tr nnUNetTrainerV2 -ctr nnUNetTrainerV2CascadeFullRes -m 3d_fullres -p nnUNetPlansv2.1 -t Task313_Eye"
# nnUNet v1 without trained model - Jaime
sudo docker run --rm --gpus all --shm-size=10gb --entrypoint=/bin/bash -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNet:/opt/nnunet_resources -e nnUNet_preprocessed=/opt/nnunet_resources/nnUNet_preprocessed -e nnUNet_raw_data_base=/opt/nnunet_resources/nnUNet_raw_data_base -e RESULTS_FOLDER=/opt/nnunet_resources/nnUNet_trained_models -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNet/nnUNet_inference:/tmp jaimebarran/fw_gear_aeye:0.0.1 -c "nnUNet_predict -i /tmp/input -o /tmp/output -tr nnUNetTrainerV2 -ctr nnUNetTrainerV2CascadeFullRes -m 3d_fullres -p nnUNetPlansv2.1 -t Task313_Eye"
# nnUNet v2 35 subs - Jaime
sudo docker run --rm --gpus all --shm-size=10gb --entrypoint=/bin/bash -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/35subs:/opt/nnunet_resources -e nnUNet_preprocessed=/opt/nnunet_resources/nnUNet_preprocessed -e nnUNet_raw=/opt/nnunet_resources/nnUNet_raw -e nnUNet_results=/opt/nnunet_resources/nnUNet_results -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/35subs/nnUNet_inference:/tmp jaimebarran/nnunet:0.1.0 -c "nnUNetv2_predict -d Dataset313_Eye -i /tmp/input -o /tmp/output -f 0 1 2 3 4 -tr nnUNetTrainer -c 3d_fullres -p nnUNetPlans"
# nnUNet v2 35 subs without custom entrypoint - Jaime
sudo docker run --rm --gpus all --shm-size=10gb -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/35subs:/opt/nnunet_resources -e nnUNet_preprocessed=/opt/nnunet_resources/nnUNet_preprocessed -e nnUNet_raw=/opt/nnunet_resources/nnUNet_raw -e nnUNet_results=/opt/nnunet_resources/nnUNet_results -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/35subs/nnUNet_inference:/tmp jaimebarran/nnunet:0.1.0 nnUNetv2_predict -d Dataset313_Eye -i /tmp/input -o /tmp/output -f 0 1 2 3 4 -tr nnUNetTrainer -c 3d_fullres -p nnUNetPlans
# nnUNet v2 74 subs - Jaime
sudo docker run --rm --gpus all --shm-size=10gb --entrypoint=/bin/bash -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/74subs:/opt/nnunet_resources -e nnUNet_preprocessed=/opt/nnunet_resources/nnUNet_preprocessed -e nnUNet_raw=/opt/nnunet_resources/nnUNet_raw -e nnUNet_results=/opt/nnunet_resources/nnUNet_results -v /home/debi/jaime/repos/a-eye/a-eye_web/nnUNetv2/74subs/nnUNet_inference:/tmp jaimebarran/nnunet:0.1.0 -c "nnUNetv2_predict -d Dataset074_AEye -i /tmp/input -o /tmp/output -f 0 1 2 3 4 -tr nnUNetTrainer -c 3d_fullres -p nnUNetPlans"
