# %%
import hashlib

password = "password"

# Hash the password
hashed_password = hashlib.sha256(password.encode()).hexdigest()

# Print the hashed password
print(hashed_password)

# %%
import os
import getpass

sudo_password = getpass.getpass("Enter sudo password: ")

# Replace `your_command_here` with the actual command you want to execute
command = f"echo {sudo_password} | sudo -S your_command_here"

os.system(command)

# %%
import os

sudo_pwd = os.environ['SUDO_PWD']
# sudo_pwd = os.system('printf $SUDO_PWD')

print(sudo_pwd)
# Out:
# Patatahitech2.0
