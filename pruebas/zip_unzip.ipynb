# %%
import zipfile, os

def unzip_file(source, destination):
    if source.split('.')[-1].lower() == 'zip':
        # Create a ZipFile object with the path of the zip file
        zip_file = zipfile.ZipFile(source)
        # Extract all the files to a folder
        zip_file.extractall(destination)
        # Close the zip file
        zip_file.close()
    
def zip_folder(source, destination):
    with zipfile.ZipFile(destination, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(source):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(source, '..')))

# %%
src = '/home/jaimebarranco/Desktop/test_inference/images/subs_dcm_nii.zip'
dst = '/mnt/sda1/Repos/a-eye/a-eye_segmentation/deep_learning/nnUNet/nnUNet/nnUNet_inference/temp_inference/input'

unzip_file(src, dst)

# %%
# src = '/home/jaimebarranco/Desktop/test_inference/output'
src = '/mnt/sda1/Repos/a-eye/a-eye_web/static/download'
dst = '/mnt/sda1/Repos/a-eye/a-eye_web/static/download/output.zip'

zip_folder(src, dst)
